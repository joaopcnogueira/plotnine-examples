# %% [markdown]
# # Reference
#
# [Plotting with plotline, part 1](https://www.practicaldatascience.org/html/plotting_part1.html)

# %%
# !pip install plotnine==0.8.0

# %%
import pandas as pd
from plotnine import *

# %%
gapminder = pd.read_csv("https://raw.githubusercontent.com/swcarpentry/r-novice-gapminder/gh-pages/_episodes_rmd/data/gapminder-FiveYearData.csv")
gapminder.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %% [markdown]
# # Basic plotnine

# %%
(
    ggplot(gapminder, aes(x="gdpPercap", y="lifeExp"))
    + geom_point()
)
# Out:
# <ggplot: (8732356428405)>

# %%
(
    ggplot(gapminder, aes(x="gdpPercap", y="lifeExp"))
    + geom_point(color="cornflowerblue", alpha=0.5, size=0.5)
)
# Out:
# <ggplot: (8732355026165)>

# %%
(
    ggplot(gapminder, aes(x="gdpPercap", y="lifeExp", color="continent"))
    + geom_point(alpha=0.5, size=0.5)
)
# Out:
# <ggplot: (8732354952565)>

# %%
(
    ggplot(gapminder, aes(x="gdpPercap", y="lifeExp", color="continent", size="pop"))
    + geom_point(alpha=0.5)
)
# Out:
# <ggplot: (8732354994017)>

# %% [markdown]
# # Types of layers

# %%
(
    ggplot(gapminder, aes(x='year', y='lifeExp', group='country', color='continent')) 
    + geom_line(alpha = 0.5)
)
# Out:
# <ggplot: (8732353241393)>

# %%
(
    ggplot(gapminder, aes(x="continent", y="lifeExp", fill="continent"))
    + geom_boxplot()
)
# Out:
# <ggplot: (8732352947857)>

# %%
(
    ggplot(gapminder, aes(x='lifeExp')) 
    + geom_histogram(binwidth = 3)
)
# Out:
# <ggplot: (8732343940693)>

# %%
# !pip install scikit-misc
(
    ggplot(gapminder, aes(x="gdpPercap", y="lifeExp", size="pop"))
    + geom_point(aes(color="continent"), alpha=0.5)
    + geom_smooth(se=False, method="loess", color="grey")
    + theme_bw()
)
# Out:
# <ggplot: (8732342915521)>

# %% [markdown]
# # Saving your plots

# %%
p = (
    ggplot(gapminder, aes(x="gdpPercap", y="lifeExp", size="pop"))
    + geom_point(aes(color="continent"), alpha=0.5)
    + geom_smooth(se=False, method="loess", color="grey")
)

# save the plot
p.save("beautiful_plotnine_plot.png")
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/ggplot.py:721: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /usr/local/lib/python3.7/dist-packages/plotnine/ggplot.py:722: PlotnineWarning: Filename: beautiful_plotnine_plot.png
